# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('/content/Music_and_Mental_Health_-_Survey.csv')

# %%
df.head()
# Out:
#          Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29  18.0                   Spotify            3.0
# 1  8/27/2022 19:57  63.0                   Pandora            1.5
# 2  8/27/2022 21:28  18.0                   Spotify            4.0
# 3  8/27/2022 21:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     736 non-null    object
#  1   Age                           735 non-null    float64
#  2   Primary streaming service     735 non-null    object
#  3   Hours per day                 736 non-null    float64
#  4   While working                 733 non-null    object
#  5   Instrumentalist               732 non-null    object
#  6   Composer                      735 non-null    object
#  7   Fav genre                     736 non-null    object
#  8   Exploratory                   736 non-null    object
#  9   Foreign languages             732 non-null    object
#  10  BPM                           629 non-null    float64
#  11  Frequency [Classical]         736 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                         0
# Age                               1
# Primary streaming service         1
# Hours per day                     0
# While working                     3
# Instrumentalist                   4
# Composer                          1
# Fav genre                         0
# Exploratory                       0
# Foreign languages                 4
# BPM                             107
# Frequency [Classical]             0
# Frequency [Country]               0
# Frequency [EDM]                   0
# Frequency [Folk]                  0
# Frequency [Gospel]                0
# Frequency [Hip hop]               0
# Frequency [Jazz]                  0
# Frequency [K pop]                 0
# Frequency [Latin]                 0
# Frequency [Lofi]                  0
# Frequency [Metal]                 0
# Frequency [Pop]                   0
# Frequency [R&B]                   0
# Frequency [Rap]                   0
# Frequency [Rock]                  0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#               Age  Hours per day           BPM     Anxiety  Depression  \
# count  735.000000     736.000000  6.290000e+02  736.000000  736.000000
# mean    25.206803       3.572758  1.589948e+06    5.837636    4.796196
# std     12.054970       3.028199  3.987261e+07    2.793054    3.028870
# min     10.000000       0.000000  0.000000e+00    0.000000    0.000000
# 25%     18.000000       2.000000  1.000000e+02    4.000000    2.000000
# 50%     21.000000       3.000000  1.200000e+02    6.000000    5.000000
# 75%     28.000000       5.000000  1.440000e+02    8.000000    7.000000
# max     89.000000      24.000000  1.000000e+09   10.000000   10.000000
#
#          Insomnia         OCD
# count  736.000000  736.000000
# mean     3.738451    2.637228
# std      3.088689    2.842017
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      3.000000    2.000000
# 75%      6.000000    5.000000
# max     10.000000   10.000000

# %%
"""df.drop(['Timestamp'], axis = 1, inplace = True)"""
# Out:
# "df.drop(['Timestamp'], axis = 1, inplace = True)"

# %%
"""df.head(2)"""
# Out:
# 'df.head(2)'

# %%
df.Age.unique()
# Out:
# array([18., 63., 61., 21., 19., nan, 17., 16., 15., 14., 20., 26., 23.,
#        37., 36., 24., 22., 42., 25., 32., 29., 41., 31., 33., 30., 43.,
#        28., 34., 13., 35., 27., 53., 49., 60., 38., 44., 40., 64., 56.,
#        59., 10., 12., 54., 57., 69., 72., 73., 39., 58., 67., 70., 55.,
#        48., 71., 74., 51., 65., 80., 50., 68., 46., 89.])

# %%
df[df.Age.isnull()]
# Out:
#           Timestamp  Age Primary streaming service  Hours per day  \
# 12  8/27/2022 23:04  NaN                   Spotify            3.0
#
#    While working Instrumentalist Composer Fav genre Exploratory  \
# 12           Yes              No       No   Hip hop         Yes
#
#    Foreign languages  ...  Frequency [R&B] Frequency [Rap] Frequency [Rock]  \
# 12               Yes  ...        Sometimes          Rarely           Rarely
#
#    Frequency [Video game music] Anxiety Depression Insomnia  OCD  \
# 12                        Never     9.0        3.0      2.0  7.0
#
#    Music effects    Permissions
# 12       Improve  I understand.
#
# [1 rows x 33 columns]

# %%
df["Age"]=df.Age.transform(lambda x: x.fillna(25))

# %%
df.Age.unique()
# Out:
# array([18., 63., 61., 21., 19., 25., 17., 16., 15., 14., 20., 26., 23.,
#        37., 36., 24., 22., 42., 32., 29., 41., 31., 33., 30., 43., 28.,
#        34., 13., 35., 27., 53., 49., 60., 38., 44., 40., 64., 56., 59.,
#        10., 12., 54., 57., 69., 72., 73., 39., 58., 67., 70., 55., 48.,
#        71., 74., 51., 65., 80., 50., 68., 46., 89.])

# %%
df["Primary streaming service"].mode()
# Out:
# 0    Spotify
# dtype: object

# %%
df["Primary streaming service"]=df["Primary streaming service"].transform(lambda x: x.fillna(x.mode().iloc[0]))

# %%
df["Primary streaming service"].unique()
# Out:
# array(['Spotify', 'Pandora', 'YouTube Music',
#        'I do not use a streaming service.', 'Apple Music',
#        'Other streaming service'], dtype=object)

# %%
df["While working"]=df["While working"].transform(lambda x: x.fillna(x.mode().iloc[0]))

# %%
df["While working"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Timestamp                         0
# Age                               0
# Primary streaming service         0
# Hours per day                     0
# While working                     0
# Instrumentalist                   4
# Composer                          1
# Fav genre                         0
# Exploratory                       0
# Foreign languages                 4
# BPM                             107
# Frequency [Classical]             0
# Frequency [Country]               0
# Frequency [EDM]                   0
# Frequency [Folk]                  0
# Frequency [Gospel]                0
# Frequency [Hip hop]               0
# Frequency [Jazz]                  0
# Frequency [K pop]                 0
# Frequency [Latin]                 0
# Frequency [Lofi]                  0
# Frequency [Metal]                 0
# Frequency [Pop]                   0
# Frequency [R&B]                   0
# Frequency [Rap]                   0
# Frequency [Rock]                  0
# ...

# %%
df["Instrumentalist"]=df["Instrumentalist"].transform(lambda x: x.fillna(x.mode().iloc[0]))

# %%
df["Instrumentalist"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df["Composer"]=df["Composer"].transform(lambda x: x.fillna(x.mode().iloc[0]))

# %%
df["Composer"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df["Foreign languages"]=df["Foreign languages"].transform(lambda x: x.fillna(x.mode().iloc[0]))

# %%
df["Foreign languages"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df["Music effects"]=df["Music effects"].transform(lambda x: x.fillna(x.mode().iloc[0]))

# %%
df["Music effects"].unique()
# Out:
# array(['Improve', 'No effect', 'Worsen'], dtype=object)

# %%
df.BPM.unique()
# Out:
# array([1.56000000e+02, 1.19000000e+02, 1.32000000e+02, 8.40000000e+01,
#        1.07000000e+02, 8.60000000e+01, 6.60000000e+01, 9.50000000e+01,
#        9.40000000e+01, 1.55000000e+02,            nan, 1.25000000e+02,
#        8.80000000e+01, 1.48000000e+02, 1.03000000e+02, 1.20000000e+02,
#        9.90000000e+01, 1.18000000e+02, 7.90000000e+01, 1.69000000e+02,
#        1.36000000e+02, 1.01000000e+02, 1.26000000e+02, 1.83000000e+02,
#        1.42000000e+02, 7.50000000e+01, 8.90000000e+01, 1.40000000e+02,
#        1.61000000e+02, 8.00000000e+01, 1.30000000e+02, 1.47000000e+02,
#        7.70000000e+01, 1.15000000e+02, 1.57000000e+02, 9.00000000e+01,
#        1.28000000e+02, 9.60000000e+01, 9.10000000e+01, 5.50000000e+01,
#        8.50000000e+01, 1.60000000e+02, 1.08000000e+02, 1.70000000e+02,
#        1.74000000e+02, 1.27000000e+02, 1.65000000e+02, 1.13000000e+02,
#        1.67000000e+02, 1.10000000e+02, 1.50000000e+02, 9.30000000e+01,
# ...

# %%
df.BPM.min()
# Out:
# 0.0

# %%
df.BPM.max()
# Out:
# 999999999.0

# %%
df.BPM.mean()
# Out:
# 1589948.344992051

# %%
df[df.BPM > 220]
# Out:
#           Timestamp   Age Primary streaming service  Hours per day  \
# 568  9/4/2022 15:41  16.0                   Spotify            7.0
# 644  9/13/2022 1:55  16.0   Other streaming service            4.0
#
#     While working Instrumentalist Composer         Fav genre Exploratory  \
# 568           Yes              No       No  Video game music         Yes
# 644           Yes              No       No               EDM         Yes
#
#     Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 568                No  ...            Never  Very frequently           Rarely
# 644               Yes  ...            Never            Never            Never
#
#     Frequency [Video game music] Anxiety Depression Insomnia  OCD  \
# 568                    Sometimes     4.0        8.0      8.0  4.0
# 644                    Sometimes     4.0        7.0      1.0  3.0
#
#     Music effects    Permissions
# 568     No effect  I understand.
# ...

# %%
df.loc[df['BPM'] > 220, 'BPM'] = 220-df.Age

# %%
df[568:645]
# Out:
#            Timestamp   Age Primary streaming service  Hours per day  \
# 568   9/4/2022 15:41  16.0                   Spotify           7.00
# 569   9/4/2022 16:26  21.0                   Spotify           1.00
# 570   9/4/2022 17:54  53.0                   Pandora           4.00
# 571   9/4/2022 20:38  29.0                   Spotify           4.00
# 572   9/4/2022 21:29  18.0                   Spotify           3.00
# ..               ...   ...                       ...            ...
# 640  9/12/2022 23:09  23.0                   Spotify           6.00
# 641  9/12/2022 23:16  30.0               Apple Music           3.00
# 642  9/12/2022 23:56  31.0                   Spotify           2.00
# 643   9/13/2022 0:48  42.0   Other streaming service           0.25
# 644   9/13/2022 1:55  16.0   Other streaming service           4.00
#
#     While working Instrumentalist Composer         Fav genre Exploratory  \
# 568           Yes              No       No  Video game music         Yes
# ...

# %%
df[df.BPM > 220]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Age, Primary streaming service, Hours per day, While working, Instrumentalist, Composer, Fav genre, Exploratory, Foreign languages, BPM, Frequency [Classical], Frequency [Country], Frequency [EDM], Frequency [Folk], Frequency [Gospel], Frequency [Hip hop], Frequency [Jazz], Frequency [K pop], Frequency [Latin], Frequency [Lofi], Frequency [Metal], Frequency [Pop], Frequency [R&B], Frequency [Rap], Frequency [Rock], Frequency [Video game music], Anxiety, Depression, Insomnia, OCD, Music effects, Permissions]
# Index: []
#
# [0 rows x 33 columns]

# %%
df[df.BPM < 40]
# Out:
#            Timestamp   Age          Primary streaming service  Hours per day  \
# 339   8/29/2022 8:37  35.0                            Spotify            3.0
# 372  8/29/2022 15:05  18.0                            Spotify            2.0
# 429  8/30/2022 18:15  73.0                            Pandora            3.0
# 524    9/2/2022 9:15  28.0                            Spotify            3.0
# 567   9/4/2022 13:07  68.0                            Pandora            1.0
# 639  9/12/2022 22:26  30.0  I do not use a streaming service.            0.0
#
#     While working Instrumentalist Composer Fav genre Exploratory  \
# 339            No             Yes       No      Folk         Yes
# 372           Yes              No       No   Hip hop         Yes
# 429           Yes              No       No       R&B         Yes
# 524            No             Yes      Yes     Metal         Yes
# 567           Yes              No       No    Gospel          No
# ...

# %%
df["BPM"][df.BPM < 40][df.Age < 61]
# Out:
# 339     0.0
# 372    20.0
# 524     0.0
# 639     0.0
# Name: BPM, dtype: float64

# %%
df.loc[(df['BPM'] < 40) & (df.Age < 61), 'BPM'] = 40

# %%
df[df.BPM < 40]
# Out:
#            Timestamp   Age Primary streaming service  Hours per day  \
# 429  8/30/2022 18:15  73.0                   Pandora            3.0
# 567   9/4/2022 13:07  68.0                   Pandora            1.0
#
#     While working Instrumentalist Composer Fav genre Exploratory  \
# 429           Yes              No       No       R&B         Yes
# 567           Yes              No       No    Gospel          No
#
#     Foreign languages  ...  Frequency [R&B] Frequency [Rap] Frequency [Rock]  \
# 429               Yes  ...  Very frequently       Sometimes        Sometimes
# 567                No  ...            Never           Never            Never
#
#     Frequency [Video game music] Anxiety Depression Insomnia  OCD  \
# 429                        Never     5.0        4.0      0.0  1.0
# 567                        Never    10.0       10.0     10.0  0.0
#
#     Music effects    Permissions
# 429       Improve  I understand.
# 567       Improve  I understand.
#
# ...

# %%
df.loc[(df['BPM'] < 40) & (df.Age > 61), 'BPM'] = 75

# %%
df[df.BPM < 40]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Age, Primary streaming service, Hours per day, While working, Instrumentalist, Composer, Fav genre, Exploratory, Foreign languages, BPM, Frequency [Classical], Frequency [Country], Frequency [EDM], Frequency [Folk], Frequency [Gospel], Frequency [Hip hop], Frequency [Jazz], Frequency [K pop], Frequency [Latin], Frequency [Lofi], Frequency [Metal], Frequency [Pop], Frequency [R&B], Frequency [Rap], Frequency [Rock], Frequency [Video game music], Anxiety, Depression, Insomnia, OCD, Music effects, Permissions]
# Index: []
#
# [0 rows x 33 columns]

# %%
df[df["BPM"] == 40]
# Out:
#            Timestamp   Age          Primary streaming service  Hours per day  \
# 339   8/29/2022 8:37  35.0                            Spotify            3.0
# 372  8/29/2022 15:05  18.0                            Spotify            2.0
# 421  8/30/2022 13:07  14.0                            Spotify            5.0
# 524    9/2/2022 9:15  28.0                            Spotify            3.0
# 639  9/12/2022 22:26  30.0  I do not use a streaming service.            0.0
#
#     While working Instrumentalist Composer  Fav genre Exploratory  \
# 339            No             Yes       No       Folk         Yes
# 372           Yes              No       No    Hip hop         Yes
# 421           Yes             Yes       No  Classical         Yes
# 524            No             Yes      Yes      Metal         Yes
# 639            No              No       No      Metal          No
#
#     Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# ...

# %%
df[df["BPM"] == 75]
# Out:
#            Timestamp   Age Primary streaming service  Hours per day  \
# 34   8/28/2022 11:08  16.0                   Spotify            1.0
# 371  8/29/2022 14:53  24.0                   Spotify            3.0
# 429  8/30/2022 18:15  73.0                   Pandora            3.0
# 452   9/1/2022 12:04  23.0                   Spotify            2.0
# 567   9/4/2022 13:07  68.0                   Pandora            1.0
#
#     While working Instrumentalist Composer  Fav genre Exploratory  \
# 34            Yes              No       No  Classical          No
# 371           Yes             Yes       No  Classical          No
# 429           Yes              No       No        R&B         Yes
# 452           Yes              No       No        Pop          No
# 567           Yes              No       No     Gospel          No
#
#     Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# ...

# %%
df.Age.min()
# Out:
# 10.0

# %%
df.Age.max()
# Out:
# 89.0

# %%
df.loc[df.Age < 19,'age_group'] = '0-18'
df.loc[(df.Age > 18) & (df.Age < 61),'age_group'] = '19-60'
df.loc[df.Age > 60,'age_group'] = '61-older'

# %%
"""df['age_group'] = df.age_group.astype(str)"""
# Out:
# "df['age_group'] = df.age_group.astype(str)"

# %%
df.head(2)
# Out:
#          Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29  18.0                   Spotify            3.0
# 1  8/27/2022 19:57  63.0                   Pandora            1.5
#
#   While working Instrumentalist Composer Fav genre Exploratory  \
# 0           Yes             Yes      Yes     Latin         Yes
# 1           Yes              No       No      Rock         Yes
#
#   Foreign languages  ...  Frequency [Rap] Frequency [Rock]  \
# 0               Yes  ...  Very frequently            Never
# 1                No  ...           Rarely  Very frequently
#
#   Frequency [Video game music] Anxiety Depression Insomnia  OCD Music effects  \
# 0                    Sometimes     3.0        0.0      1.0  0.0       Improve
# 1                       Rarely     7.0        2.0      2.0  1.0       Improve
#
#      Permissions age_group
# 0  I understand.      0-18
# 1  I understand.  61-older
#
# [2 rows x 34 columns]

# %%
print(type(df.age_group))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df[df.BPM.isnull()]
# Out:
#            Timestamp   Age          Primary streaming service  Hours per day  \
# 10   8/27/2022 22:51  18.0                            Spotify            3.0
# 12   8/27/2022 23:04  25.0                            Spotify            3.0
# 15   8/27/2022 23:19  17.0                            Spotify            2.0
# 30   8/28/2022 10:30  20.0                        Apple Music            5.0
# 32   8/28/2022 10:54  19.0                            Spotify            6.0
# ..               ...   ...                                ...            ...
# 688   9/24/2022 0:42  18.0                            Spotify            4.0
# 700  10/3/2022 10:00  20.0                      YouTube Music            1.0
# 706  10/3/2022 15:38  23.0                            Spotify            1.0
# 712   10/4/2022 8:53  23.0  I do not use a streaming service.            3.0
# 717  10/5/2022 12:30  23.0                            Spotify            2.0
#
# ...

# %%
df.BPM.mean()
# Out:
# 123.32591414944356

# %%
df.groupby('age_group')['BPM'].mean()
# Out:
# age_group
# 0-18        123.047170
# 19-60       123.972569
# 61-older    110.812500
# Name: BPM, dtype: float64

# %%
df.loc[(df.BPM.isnull()) & (df['age_group'] == "0-18"), 'BPM'] = 123

# %%
df.loc[(df.BPM.isnull()) & (df['age_group'] == "19-60"), 'BPM'] = 124

# %%
df.loc[(df.BPM.isnull()) & (df['age_group'] == "61-older"), 'BPM'] = 111

# %%
df.BPM.unique()
# Out:
# array([156., 119., 132.,  84., 107.,  86.,  66.,  95.,  94., 155., 123.,
#        125., 124.,  88., 148., 103., 120.,  99., 118.,  79., 169., 136.,
#        101., 126., 183., 142.,  75.,  89., 140., 161.,  80., 130., 147.,
#         77., 115., 157.,  90., 128.,  96.,  91.,  55.,  85., 160., 108.,
#        170., 174., 127., 165., 113., 167., 110., 150.,  93., 109., 175.,
#        162., 189., 121., 200., 105., 193., 149., 134., 100.,  98.,  78.,
#        117., 122., 179., 166., 144.,  61., 185.,  92., 194.,  60., 190.,
#         87., 171., 114., 141., 146., 164., 145., 112., 111., 172., 180.,
#         76., 129.,  81.,  52.,  97., 143., 158., 104., 135., 220., 138.,
#        139., 178.,  62.,  72.,  40., 208., 181., 106., 191., 173.,  73.,
#        137., 133., 102.,  82., 116., 131., 204., 159.,  70., 210., 153.,
#        192.,  56.,  63.,  68., 218., 186., 163., 168.])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     736 non-null    object
#  1   Age                           736 non-null    float64
#  2   Primary streaming service     736 non-null    object
#  3   Hours per day                 736 non-null    float64
#  4   While working                 736 non-null    object
#  5   Instrumentalist               736 non-null    object
#  6   Composer                      736 non-null    object
#  7   Fav genre                     736 non-null    object
#  8   Exploratory                   736 non-null    object
#  9   Foreign languages             736 non-null    object
#  10  BPM                           736 non-null    float64
#  11  Frequency [Classical]         736 non-null    object
# ...

# %%
df.head(2)
# Out:
#          Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29  18.0                   Spotify            3.0
# 1  8/27/2022 19:57  63.0                   Pandora            1.5
#
#   While working Instrumentalist Composer Fav genre Exploratory  \
# 0           Yes             Yes      Yes     Latin         Yes
# 1           Yes              No       No      Rock         Yes
#
#   Foreign languages  ...  Frequency [Rap] Frequency [Rock]  \
# 0               Yes  ...  Very frequently            Never
# 1                No  ...           Rarely  Very frequently
#
#   Frequency [Video game music] Anxiety Depression Insomnia  OCD Music effects  \
# 0                    Sometimes     3.0        0.0      1.0  0.0       Improve
# 1                       Rarely     7.0        2.0      2.0  1.0       Improve
#
#      Permissions age_group
# 0  I understand.      0-18
# 1  I understand.  61-older
#
# [2 rows x 34 columns]

# %%
df.describe()
# Out:
#               Age  Hours per day         BPM     Anxiety  Depression  \
# count  736.000000     736.000000  736.000000  736.000000  736.000000
# mean    25.206522       3.572758  123.300272    5.837636    4.796196
# std     12.046769       3.028199   30.469671    2.793054    3.028870
# min     10.000000       0.000000   40.000000    0.000000    0.000000
# 25%     18.000000       2.000000  105.000000    4.000000    2.000000
# 50%     21.000000       3.000000  123.000000    6.000000    5.000000
# 75%     28.000000       5.000000  140.000000    8.000000    7.000000
# max     89.000000      24.000000  220.000000   10.000000   10.000000
#
#          Insomnia         OCD
# count  736.000000  736.000000
# mean     3.738451    2.637228
# std      3.088689    2.842017
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      3.000000    2.000000
# 75%      6.000000    5.000000
# max     10.000000   10.000000

# %%
df.hist(figsize=(10,8));

# %%
print(df.corr())
# Out:
#                     Age  Hours per day       BPM   Anxiety  Depression  \
# Age            1.000000      -0.044632 -0.016156 -0.176534   -0.121520
# Hours per day -0.044632       1.000000  0.023032  0.049319    0.110527
# BPM           -0.016156       0.023032  1.000000  0.025857    0.039606
# Anxiety       -0.176534       0.049319  0.025857  1.000000    0.519969
# Depression    -0.121520       0.110527  0.039606  0.519969    1.000000
# Insomnia       0.006920       0.141821  0.041929  0.292669    0.378996
# OCD           -0.129940       0.118729 -0.023015  0.348350    0.196988
#
#                Insomnia       OCD
# Age            0.006920 -0.129940
# Hours per day  0.141821  0.118729
# BPM            0.041929 -0.023015
# Anxiety        0.292669  0.348350
# Depression     0.378996  0.196988
# Insomnia       1.000000  0.226354
# OCD            0.226354  1.000000

# %%
df.to_csv(r'/content/cleaned_Survey.csv', index=False, header=True)
